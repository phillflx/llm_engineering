# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports

from openai import OpenAI
from dotenv import load_dotenv
import os
from IPython.display import display, Markdown, update_display

# %%
# constants

load_dotenv(override=True)
MODEL_GPT = 'gpt-4o-mini'
API_KEY = os.getenv('OPENAI_API_KEY')
MODEL_LLAMA = 'llama3.2'
BASE_API_URL = 'http://localhost:11434/v1'

# %%
   
client = OpenAI(base_url=BASE_API_URL, api_key='ollama')

system_prompt = """
You are a technical coding assistant
You will receive a question
You should answer with a detailed explanation
Use markdown to format and emphasize important terms
"""

def get_messages_for(question):
    messages = [
        { 'role': 'system', 'content': system_prompt },
        { 'role': 'user', 'content': question }
    ]
    
    return messages

def get_answer_for(question, stream=False):
    messages = get_messages_for(question)
    response = client.chat.completions.create(
        model=MODEL_LLAMA,
        messages=messages,
        stream=stream
    )

    return response

def print_answer_for(question):
    response = get_answer_for(question)
    answer = response.choices[0].message.content

    display(Markdown(answer))

def print_answer_as_stream_for(question):
    stream = get_answer_for(question, stream=True)
    display_handle = display(Markdown(''), display_id=True)
    response =  ''

    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming
print_answer_as_stream_for(question)
# Out:
# **Code Breakdown**
# ===============
#
# The given code is a Python expression that utilizes a combination of generator expressions and the `yield from` keyword. Let's break it down:
#
# **`yield from` Keyword**
# ---------------------
#
# `yield from` is a Python keyword that introduces a new generation, effectively allowing us to "yield" values from another generator.
#
# **Generator Expression**
# ----------------------
#
# The generator expression inside the parentheses is another way of writing a list comprehension, but instead of evaluating the expression immediately and returning the result, it generates values on-the-fly.
#
# **`{book.get("author") for book in books if book.get("author")}`**
# -----------------------------------------------------------
#
# This is a generator expression that:
#
# * Iterates over the `books` collection.
# * Filters out books that don't have an "author" key using the `if book.get("author")` condition.
# * Yields the value of the "author" key for each book that passes the filter using the `book.get("author")` expression.
#
# **Putting it all Together**
# ---------------------------
#
# When we put the `yield from` keyword in front of the generator expression, we're telling Python to:
#
# 1. Iterate over the `books` collection.
# 2. For each book, filter out those that don't have an "author" key.
# 3. Yield the "author" value for each book that passes the filter.
#
# **What does it do?**
# ------------------
#
# In summary, this code is likely used in a context where we need to process a collection of books, and we want to extract and yield the "author" value for each book. The filtering is performed to avoid infinite loops or errors that could occur if some books didn't have the "author" key.
#
# **Example Use Case**
# --------------------
#
# Here's an example of how you might use this code:
# ```python
# books = [
#     {"title": "Book 1", "author": "Author 1"},
#     {"title": "Book 2", "author": "Author 2"},
#     {"title": "Book 3", "author": None},  # No author key
# ]
#
# # Get the authors from the books
# authors = yield from {book.get("author") for book in books if book.get("author")}
#
# # Print the authors
# print(authors)  # Output: ["Author 1", "Author 2"]
# ```
# In this example, we define a `books` collection, and then use the generator expression to extract and yield the "author" values for each book that has an "author" key. The resulting authors are stored in the `authors` variable and can be used in further processing.

# %%
# Get Llama 3.2 to answer
print_answer_for(question)
# Out:
# **Code Explanation**
# ===============
#
# The provided code is written in Python and utilizes the `yield from` keyword to extract data from an iterable object called `books`.
#
# ### Breaking Down the Code
#
# ```python
# yield from {book.get("author") for book in books if book.get("author")}
# ```
#
# *   **`yield from`**: This is a Python 3.3+ keyword that allows us to delegate subexpression iterations to another generator.
# *   **Dictionary Comprehension**: `{book.get("author") for book in books if book.get("author")}`
#     *   This comprehension iterates over the `books` iterable and filters out books that are missing the `"author"` key.
#     *   For each book that is valid, it extracts the author name using the `get()` method and yields it as part of the dictionary comprehension.
#
# ### How it Works
#
# 1.  The inner list comprehension filters the `books` iterable to include only books that have a `"author"` key.
# 2.  For each valid book, the `get()` method is called on the book object to retrieve the author's name.
# 3.  The author's name is then yielded as part of the dictionary comprehension, essentially "providing" it to the outer iterable.
# 4.  The `yield from` keyword tells Python to delegate the iteration over the resulting iterable of author names to the `yield from` generator expression.
#
# ### Example Use Case
#
# Suppose we have a list of book objects, and we want to extract the author's names from each book:
#
# ```python
# import json
#
# # Sample book data
# books = [
#     {"title": "Book 1", "author": "John Doe"},
#     {"title": "Book 2", "author": None},
#     {"title": "Book 3", "author": "Jane Doe"},
# ]
#
# def get_authors(books):
#     yield from {book.get("author") for book in books if book.get("author")}
#
# # Iterate over the authors
# for author in get_authors(books):
#     print(author)
# ```
#
# Output:
#
# ```
# John Doe
# Jane Doe
# ```
#
# In this example, we define a generator `get_authors` that uses the `yield from` keyword to extract the author's names from a list of book objects. The resulting generator expression is then iterated over to print the authors' names.
