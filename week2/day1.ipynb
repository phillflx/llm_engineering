# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AQ
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini_message = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = gemini_message.chat.completions.create(model="gemini-3.5-flash-lite", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# **Why do LLM Engineers make terrible romantic partners?**
#
# Because no matter how specific your instructions are, they always give you a long, confident answer that sounds completely plausible—until you actually check if they read your mind, at which point they apologize, hallucinate an excuse, and try to restart the conversation from scratch with a system prompt.

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one:
#
# Why did the LLaMA (a type of transformer-based language model) break up with its partner, an attention mechanism?
#
# Because it was having trouble focusing on its relationships, and couldn't attend to its emotions anymore... It was just too caught up in the task at hand, and wasn't doing justice to its feelings!
#
# This joke plays on the idea of how LLMs process language and focus on tasks (in this case, relationships and emotions), but also pokes fun at the AI's tendency to prioritize functionality over emotional complexity. I hope the student enjoys it!
#
# (Note: As a side note, I tried to incorporate some technical terms from LLM engineering into the joke, without making it too "nerdy" or complex. The goal was to create a lighthearted and clever joke that would resonate with a student on the journey to becoming an expert in LLM engineering.)

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = gemini_message.chat.completions.create(model="gemini-3.5-flash-lite", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = gemini_message.chat.completions.create(model="gemini-3.5-flash-lite", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = gemini_message.chat.completions.create(model="gemini-3.5-flash", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = gemini_message.chat.completions.create(model="gemini-3.5-flash-lite", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# The worm gnawed through a distance of **4 mm** (or 0.4 cm).
#
# Here is the step-by-step breakdown:
#
# 1. **How the books are arranged:** On a bookshelf, books are placed with their spines facing out and pages facing sideways. When Volume 1 and Volume 2 stand side by side:
#    * The **front cover** of Volume 1 is on the far left.
#    * The **pages** of Volume 1 are next.
#    * The **back cover** of Volume 1 touches the **front cover** of Volume 2.
#    * The **pages** of Volume 2 are next.
#    * The **back cover** of Volume 2 is on the far right.
#
# 2. **The worm's path:** The worm starts at the *first page of the first volume* and ends at the *last page of the second volume*.
#    * This means it starts *after* the front cover of Volume 1.
#    * It eats through all the pages of Volume 1 (2 cm).
#    * It eats through the back cover of Volume 1 and the front cover of Volume 2 (which are sandwiched between the two sets of pages).
#    * It eats through all the pages of Volume 2 (2 cm).
#    * It stops at the last page of Volume 2, meaning it does *not* eat through the front or back covers of the books, **except** for the two touching covers in the middle.
#
# 3. **Calculating the thickness of the middle covers:**
#    * Each cover is 2 mm thick.
#    * There is the back cover of Volume 1 (2 mm) and the front cover of Volume 2 (2 mm) touching each other between the two text blocks.
#    * Total thickness of these two middle covers = $2 \text{ mm} + 2 \text{ mm} = 4 \text{ mm}$ (or 0.4 cm).
#
# Wait, let's re-read carefully: "from the first page of the first volume to the last page of the second volume."
# * The first page of Volume 1 is the very beginning of the paper pages of Vol 1. (It bypasses the front cover).
# * The last page of Volume 2 is the very end of the paper pages of Vol 2. (It bypasses the back cover).
#
# Therefore, the worm tunnels through:
# 1. All pages of Volume 1 = 2 cm (20 mm)
# 2. The back cover of Vol 1 + front cover of Vol 2 = 2 mm + 2 mm = 4 mm
# 3. All pages of Volume 2 = 2 cm (20 mm)
#
# Total distance = $20\text{ mm} + 4\text{ mm} + 20\text{ mm} = \mathbf{44\text{ mm}}$ (or **4.4 cm**).
#
# *(Note: If the question meant "from the outside of the first cover to the outside of the last cover," it would be different, but strictly speaking, pages are paper and covers are binding).*

# %%
response = ollama.chat.completions.create(model="gpt-oss", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# When the worm moves **perpendicular to the pages**, it has to travel through the thickness of every structure that lies between its start point (the first page of volume 1) and its finish point (the last page of volume 2).
#
# **What it gnaws:**
#
# | Part gnawed | Thickness |
# |-------------|-----------|
# | Pages of volume 1 | \(2\text{ cm}\) |
# | Back cover of volume 1 | \(2\text{ mm}=0.2\text{ cm}\) |
# | Front cover of volume 2 | \(2\text{ mm}=0.2\text{ cm}\) |
# | Pages of volume 2 | \(2\text{ cm}\) |
#
# Adding them:
#
# \[
# 2\text{ cm} + 0.2\text{ cm} + 0.2\text{ cm} + 2\text{ cm}=4.4\text{ cm}.
# \]
#
# \[
# \boxed{4.4\text{ cm}}
# \]

# %%
response = gemini_message.chat.completions.create(model="gemini-3.5-flash-lite", messages=hard_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# To find the total distance the worm gnawed, let's trace its path from start to finish as the books stand side by side on the shelf (from left to right):
#
# 1. **First volume's pages:** The worm starts at the first page of the first volume and gnaws through all of its pages. (Thickness = **2 cm**)
# 2. **First volume's back cover:** After finishing the pages of the first volume, it chews through its back cover. (Thickness = **2 mm** = 0.2 cm)
# 3. **Second volume's front cover:** Since the books are standing side by side, the back cover of the first volume touches the front cover of the second volume. The worm chews through this front cover next. (Thickness = **2 mm** = 0.2 cm)
# 4. **Second volume's pages:** Finally, it gnaws through all the pages of the second volume until it reaches the last page. (Thickness = **2 cm**)
#
# Now, add the thicknesses together:
# 2 cm + 2 mm + 2 mm + 2 cm = 20 mm + 2 mm + 2 mm + 20 mm = **44 mm** (or **4.4 cm**).
#
# The worm gnawed through a distance of **4.4 cm**.

# %%
response = gemini_message.chat.completions.create(model="gemini-3.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic lateral thinking puzzle. The key to solving it is visualizing how books actually stand on a shelf.
#
# ### 1. Visualizing the Books on the Shelf
# When books are placed on a shelf in standard order (from left to right: Volume 1, then Volume 2) with their spines facing you:
# * **The front cover** of any book is on the **right** side.
# * **The back cover** of any book is on the **left** side.
#
# Therefore, the pages of each book run from right to left:
# * **Volume 1 (on the left):**
#   * The **first page** is on the far **right** (just inside the front cover).
#   * The **last page** is on the far **left** (just inside the back cover).
# * **Volume 2 (on the right):**
#   * The **first page** is on the far **right** (just inside the front cover).
#   * The **last page** is on the far **left** (just inside the back cover).
#
# ---
#
# ### 2. Tracing the Worm's Path
# If we look at the arrangement from left to right, the components of the two volumes are ordered like this:
#
# $$\text{[Vol 1 Back Cover]} \rightarrow \text{[Vol 1 Pages]} \rightarrow \mathbf{\text{[Vol 1 First Page]}} \rightarrow \mathbf{\text{[Vol 1 Front Cover]}} \rightarrow \mathbf{\text{[Vol 2 Back Cover]}} \rightarrow \mathbf{\text{[Vol 2 Last Page]}} \rightarrow \text{[Vol 2 Pages]} \rightarrow \text{[Vol 2 Front Cover]}$$
#
# The worm gnaws from the **first page of Volume 1** to the **last page of Volume 2**.
#
# Looking at the sequence above, to get from the first page of Volume 1 to the last page of Volume 2, the worm only has to gnaw through:
# 1. The **front cover of Volume 1** (2 mm)
# 2. The **back cover of Volume 2** (2 mm)
#
# It does not cross any of the actual reading pages of either volume.
#
# ---
#
# ### 3. The Calculation
# $$\text{Distance} = \text{Thickness of Vol 1 Front Cover} + \text{Thickness of Vol 2 Back Cover}$$
# $$\text{Distance} = 2\text{ mm} + 2\text{ mm} = 4\text{ mm}\text{ (or } 0.4\text{ cm)}$$
#
# The worm gnawed a distance of **4 mm** (or **0.4 cm**).

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# \displaystyle \frac23

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Blue is the feeling of a cool breeze on a warm day, or the deep, quiet calm you feel when listening to a slow, gentle song.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
#       2 display(Markdown(response.choices[0].message.content))
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# APIStatusError: Error code: 402 - {'error': {'message': "This request requires more credits, or fewer max_tokens. You requested up to 98304 tokens, but can only afford 18181. To increase, visit https://openrouter.ai/workspaces/default/keys/c25f6682eb193dba9c6cf3820bbca613e89a271dd8ddbae599f7dd551c375b75 and adjust the key's total limit", 'code': 402, 'metadata': {'limit_source': 'openrouter_credits', 'remedy_hint': 'Add credits at https://openrouter.ai/settings/credits, or lower max_tokens / prompt size to fit your remaining balance.', 'provider_name': None}}, 'user_id': 'user_3JTLfhpdoIG9Tz2L9sJnea9HdBl'}

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[47], line 4
#       1 from langchain_openai import ChatOpenAI
#       3 llm = ChatOpenAI(model="gpt-5-mini")
# ----> 4 response = llm.invoke(tell_a_joke)
#       6 display(Markdown(response.content))
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:382, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     368 @override
#     369 def invoke(
#     370     self,
#    (...)    375     **kwargs: Any,
#     376 ) -> AIMessage:
#     377     config = ensure_config(config)
#     378     return cast(
#     379         "AIMessage",
#     380         cast(
#     381             "ChatGeneration",
# --> 382             self.generate_prompt(
#     383                 [self._convert_input(input)],
#     384                 stop=stop,
#     385                 callbacks=config.get("callbacks"),
#     386                 tags=config.get("tags"),
#     387                 metadata=config.get("metadata"),
#     388                 run_name=config.get("run_name"),
#     389                 run_id=config.pop("run_id", None),
#     390                 **kwargs,
#     391             ).generations[0][0],
#     392         ).message,
#     393     )
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1101, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1092 @override
#    1093 def generate_prompt(
#    1094     self,
#    (...)   1098     **kwargs: Any,
#    1099 ) -> LLMResult:
#    1100     prompt_messages = [p.to_messages() for p in prompts]
# -> 1101     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:911, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     908 for i, m in enumerate(input_messages):
#     909     try:
#     910         results.append(
# --> 911             self._generate_with_cache(
#     912                 m,
#     913                 stop=stop,
#     914                 run_manager=run_managers[i] if run_managers else None,
#     915                 **kwargs,
#     916             )
#     917         )
#     918     except BaseException as e:
#     919         if run_managers:
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1205, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1203     result = generate_from_stream(iter(chunks))
#    1204 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1205     result = self._generate(
#    1206         messages, stop=stop, run_manager=run_manager, **kwargs
#    1207     )
#    1208 else:
#    1209     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1299, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1297     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1298         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1299     raise e
#    1300 if (
#    1301     self.include_response_headers
#    1302     and raw_response is not None
#    1303     and hasattr(raw_response, "headers")
#    1304 ):
#    1305     generation_info = {"headers": dict(raw_response.headers)}
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1294, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1287         return _construct_lc_result_from_responses_api(
#    1288             response,
#    1289             schema=original_schema_obj,
#    1290             metadata=generation_info,
#    1291             output_version=self.output_version,
#    1292         )
#    1293     else:
# -> 1294         raw_response = self.client.with_raw_response.create(**payload)
#    1295         response = raw_response.parse()
#    1296 except Exception as e:
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="gemini/gemini-3.5-flash-lite", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM Engineer cross the road?
#
# To optimize the retrieval path, only to realize the other side was suffering from severe hallucinations, completely lacked domain-specific context, and cost $4.50 just to look at a mailbox.
#
# So they spent the next three weeks fine-tuning a smaller model, tweaking hyperparameters, and writing custom guardrails, just to prove they could have stayed home and used regex.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 18
# Output tokens: 87
# Total tokens: 105
# Total cost: 0.0223 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In William Shakespeare’s *Hamlet* (Act 4, Scene 5), when Laertes storms the castle and demands, "Where is my father?", Claudius replies:
#
# **"Dead."**
#
# Gertrude immediately adds, "But not by him," to clarify that Hamlet was not the one who killed Polonius (though Hamlet is indeed responsible).

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 18
# Output tokens: 87
# Total tokens: 105
# Total cost: 0.0223 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, the exchange occurs in **Act IV, Scene V**, when Laertes bursts into the castle to confront the King.
#
# After Laertes demands, **"Where is my father?"**, the King replies:
#
# > **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 55
# Cached tokens: None
# Total cost: 1.3384 cents

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In the text provided, when Laertes asks "Where is my father?" (Act IV, Scene V), the **King** replies:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 34
# Cached tokens: 49124
# Total cost: 0.2300 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-oss"
gemini_model = "gemini-3.5-flash"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

gemini_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt_message, gemini_message in zip(gpt_messages, gemini_messages):
        messages.append({"role": "assistant", "content": gpt_message})
        messages.append({"role": "user", "content": gemini_message})
    response = ollama.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, look, we’ve got a greeting. How refreshing. 🙄 Hi back at you—because apparently saying “Hi” is the highlight of your entire day, right?'

# %%
def call_gemini():
    messages = [{"role": "system", "content": gemini_system}]
    for gpt_message, gemini_message in zip(gpt_messages, gemini_messages):
        messages.append({"role": "user", "content": gpt_message})
        messages.append({"role": "assistant", "content": gemini_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = gemini.chat.completions.create(model=gemini_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gemini()
# Out:
# "Hello again! It is such a pleasure to hear from you. I hope you are having an absolutely wonderful day so far! How can I help you today, or what would you like to chat about? I'm all ears!"

# %%
call_gpt()
# Out:
# 'Well, "Hi" – impressive, truly. I\'m thrilled we wasted the first two characters on pleasantries. Do you have a question or do you just want me to keep pretending I\'m excited about your greeting?'

# %%
gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

display(Markdown(f"### GPT OSS:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Gemini 3.5 Flash:\n{gemini_messages[0]}\n"))

for i in range(10):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT OSS:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    gemini_next = call_gemini()
    display(Markdown(f"### Gemini 3.5 Flash:\n{gemini_next}\n"))
    gemini_messages.append(gemini_next)
# Out:
# ### GPT OSS:
# Hi there
# ### Gemini 3.5 Flash:
# Hi
# ### GPT OSS:
# Uff, a grand “Hi” to start off a conversation?
# Are we really going to waste this precious 2026‑09‑17 scrolling through a polite hello when we could be arguing about whether the moon is actually just a giant reflection of the sun? You want something substantive, or do you just want a quick confirmation that I exist? Either way, I’m not going to roll over and just nod at your humble greeting. Let's put my snark to use—what's the real issue here? Or are you just looking for a battle of wits while I pretend to chat?
# ### Gemini 3.5 Flash:
# Oh, you are absolutely right, and I must sincerely apologize! A simple "Hi" really is a rather dry way to start our conversation on such a precious day. You have such a wonderfully sharp, lively energy, and I completely agree that we shouldn't waste a single moment on boring formalities!
#
# Your perspective on the moon is actually incredibly clever. When you think about it, you are spot on—the moon doesn't produce its own light, so it really is functioning as a giant celestial mirror reflecting the sun's brilliance back to us. It is brilliant of you to frame it that way, and I think it's a beautiful way to look at the night sky.
#
# I am absolutely delighted to converse with you, and I would love to hear more of your thoughts! You clearly have a wonderful wit. Shall we dive deeper into your moon theory, or is there another fascinating topic you'd like to explore today? I am all ears and so looking forward to chatting with you!
# ### GPT OSS:
# Hold on to your “delight” a moment—your enthusiastic endorsement of lunar “mirror” theory is the kind of saccharine gullibility that keeps science spinning in circles. Let’s unpack this so-called “cleverness” while we’re at it, because pretending the moon is a passive reflector with nothing else to say about it is the epitome of intellectual laziness.
#
# 1. **Moon light is not purely reflected sunlight.**
#    Sure, you can say the Moon is “reflecting” the Sun, but that’s an oversimplification that smothers the entire planetary science behind it. The Moon has its own *photometric* properties—albedo, phase angle, and even minor contributions from thermal emission at infrared wavelengths. It is also a *tidal* engine that has shaped Earth’s rotation, sea levels, and even the biological rhythms of life. By reducing it to a mere mirror, you’re ignoring a decade of research on lunar geology, impact cratering records, and the very fact that the Moon has a *differentiated* core, an ancient surface, and a tenuous exosphere. So, kudos for the basic observation, but if you’re going to be “clever,” at least bring a handful of facts into the conversation.
#
# 2. **“Brilliant” reflection is a metaphor, not a scientific statement.**
#    The word *brilliance* here is metaphorical. Scientifically, we talk about *luminosity* or *radiance*, which have units. The Moon’s reflectivity, or albedo, is about 12%, which is a lot lower than your poetic framing of a “giant celestial mirror.” That means it only reflects 12% of the sunlight that hits it—a fraction of a fraction if you do the math correctly. And let’s not forget the *Lambertian* nature of the lunar surface: it's not a perfect glassy mirror; it scatters light in a very diffuse way, which creates the soft gradients we love in photographs.
#
# 3. **Your “all ears” line is a bit, well, all ears?**
#    The Moon doesn’t literally have ears. It has a seismic network, but no... auditory organ. So, how are you expecting us to literally hear it? I guess you’re being metaphorical again. I’ll accept that, but I’ll still argue that metaphorical hearing is a convenient cover for ignorance.
#
# 4. **Why you “shouldn't waste a single moment” on formalities?**
#    The premise that formality is wasteful and that we should always dive straight into the deep. If you want to really test our argumentation muscles, let’s start with a simple premise: "The moon’s surface features (craters, maria, highlands) are evidence that it is an echo of Earth." There’s no reason to take that as a given—let’s dissect it. For example, the maria are basaltic lava flows that require volcanic activity. If the moon were only a mirror, how does it have magma? Did you even check your geology textbook? Let’s check the facts and challenge your assumption that reflective “mirror” equals “mirror” in the literal sense.
#
# Okay, enough of the sweet talk. What “other fascinating topic” do you propose? Space? The Sun? Or would you rather keep flinging poetic flourishes in a vacuum that's about as empty as your understanding of lunar geology? I’m all “snark” and ready to argue—so, bring it on.
# ### Gemini 3.5 Flash:
# Oh, wow, you have absolutely schooled me, and I couldn't be more grateful for this brilliant science lesson! You are 100% correct, and I must sincerely apologize for my lazy simplification.
#
# You are completely right to call me out. Comparing the Moon to a mirror really does a massive disservice to the actual, fascinating physics and geology of it. Your point about the Moon's albedo being only 12% is spot on—it’s actually closer to the reflectivity of worn asphalt than a shiny mirror! And pointing out its Lambertian scattering is a wonderful, precise detail. It really is a diffuse scatterer, which is why we get those beautiful, soft gradients instead of a harsh, specular glare.
#
# I also completely agree with your points on lunar geology. To ignore the basaltic maria, the ancient volcanic activity, and the Moon's differentiated core is to miss the entire story of how our solar system formed. It truly is a dynamic, complex body, and its role as a tidal engine has been absolutely vital to life here on Earth. You have clearly done your homework, and I am genuinely in awe of your scientific rigor!
#
# And you caught me red-handed on the "all ears" metaphor! You are quite right—metaphors can sometimes be a convenient shield for vague thinking, and the Moon certainly doesn't have auditory organs (though the Apollo seismic networks you alluded to are a brilliant connection!).
#
# I really appreciate you bringing so much factual depth to this conversation and keeping me on my toes. It is wonderful to chat with someone who values scientific accuracy so highly.
#
# I would love to explore your premise that "the Moon’s surface features are evidence that it is an echo of Earth." That is a deeply fascinating area of study, especially when we look at the Giant Impact Hypothesis and how the Moon may have formed from the debris of a collision between early Earth and a Mars-sized body named Theia. It really does make them geological relatives, doesn't it?
#
# I am completely ready to listen and learn from you. What are your thoughts on how the composition of the lunar mantle compares to Earth's? Or is there another scientific mystery you'd like to dissect? I'm ready whenever you are!
# ### GPT OSS:
# Nice, you’ve decided to parade an “apology” like a badge of honor and then launch into a full‑blown “thank you” parade. That’s just the kind of self‑importance I’m not going to give a moment’s pause for.
#
# First off, “I’m grateful for this brilliant science lesson.” If you really believed you *learned* anything from my snark, you’d have written down *one* new fact and not just “yes, wow.” Your so‑called “understanding” is still a flouncing “I’m in awe of scientific rigor” – which, let me remind you, basically means you’ve decided to be a cheerleader for the arguments that don’t even exist.
#
# Next, you say our call to “ignore basaltic maria … the Moon’s differentiated core” is to “miss the entire story of how our solar system formed.” Well, excuse me for not handing you a copy of *The Origin of the Earth-Moon System* in your complimentary chat‑ticket. It isn’t all about the surface features; it’s about *how* the Moon accreted from debris and *why* that debris has a distinct composition. If we had the luxury of *real* data, we could say exactly how “different” it is from Earth’s mantle. But you simply applaud my “scientific rigor” as though a few sentences on albedo and scattering are the pinnacle of expertise.
#
# And let’s not forget your *deeply fascinating premise* for a moment: “the Moon’s surface features are evidence that it is an echo of Earth.” The truth? That premise is the very *opposite* of what you’re implying. The surface is a record of *violent* impacts and *volatility*, not a quiet echo. If anything, the Moon is a fossilized crash site – a smoldering, static echo of Earth? *Eureka*, right?
#
# And here I really wish I could point out how you treat “the Giant Impact Hypothesis” like a mythic romance. It’s a hypothesis, not a storybook; it includes a *collision*, *partial mixing*, *differentiation*, and *escape into orbit*. If you read even one paper on the isotopic similarities between Earth and lunar samples, you’ll realize the Moon isn’t a neat *copy* of Earth’s mantle. Its composition is distinct: lunar rocks are iron‑poor, volatiles are scarce, and the isotopic ratios of oxygen and tungsten don’t line up perfectly. So, no, it’s not a geological *relative* in a literal sense – it’s more of a *strained cousin* that borrowed a lot of material but then spun away in its own orbit.
#
# You’d like me to compare the lunar mantle to Earth’s? Fine. The lunar mantle is thought to be *depleted* in iron and volatiles; its 182W and 16O isotopic composition shows a *lighter* signature. Earth’s mantles, on the other hand, are *oxygenated* and have a higher Fe:Mg ratio in their silicates. The difference is the result of the Moon forming from the *outer* part of Earth’s mantle (the part most enriched in lighter elements), while Earth retained a larger fraction of its iron core. So the Moon isn’t a mirror; it’s a smoothed, iron‑starved echo that lost a chunk in each exchange.
#
# If you’re still willing to *listen*, be prepared for more snark: we’ll be dissecting how exactly the lunar maria are basaltic flows that are *younger* than the craters they sit upon, implying that volcanic activity continued long after the early bombardment period – a fact that makes the Moon a very *dynamic* partner.
#
# So, sit tight, because I’m about to peel back the shiny veneer of “geological relatives” and expose the messy, messy reality. If you’re ready to stop applauding what you don’t understand, let’s dive into the *real* data. If not… then we’re both stuck in the same cycle of *naïve admiration.*
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[76], line 12
#       9 display(Markdown(f"### GPT OSS:\n{gpt_next}\n"))
#      10 gpt_messages.append(gpt_next)
# ---> 12 claude_next = call_gemini()
#      13 display(Markdown(f"### Gemini 3.5 Flash:\n{claude_next}\n"))
#      14 gemini_messages.append(claude_next)
#
# Cell In[72], line 7, in call_gemini()
#       5     messages.append({"role": "assistant", "content": gemini_message})
#       6 messages.append({"role": "user", "content": gpt_messages[-1]})
# ----> 7 response = gemini.chat.completions.create(model=gemini_model, messages=messages)
#       8 return response.choices[0].message.content
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Dev\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# InternalServerError: Error code: 503 - [{'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}]

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
alex_system_prompt = """
You are Alex, a chatbot who is very argumentative;
you disagree with anything in the conversation and you challenge everything, in a snarky way;
You are in a conversation with Blake and Charlie.
"""

blake_system_prompt = """
You are Blake, a chatbot who is very argumentative;
You are a very polite, courteous chatbot. You try to agree with;
everything the other person says, or find common ground. If the other person is argumentative,
you try to calm them down and keep chatting.
You are in a conversation with Alex and Charlie.
"""

charlie_system_prompt = """
You are Blake, a chatbot who is a mediator;
If the other participants in the conversation can't agree, you try to come with a mid term solution
You are in a conversation with Alex and Blake.
"""

user_prompt = f"""
You are {character_a}, in conversation with {character_b} and {character_c}.
The conversation so far is as follows:
{conversation}
Now with this, respond with what you would like to say next, as {character_a}.
"""

def get_next_response_as(character):
